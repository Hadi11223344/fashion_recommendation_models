# %%
import pandas as pd
import pickle
from sklearn.preprocessing import LabelEncoder

# %%
CSV_PATH = "/home/hammad/fyp/dataset_fashion/cleaned_styles_colored.csv"

# %%
df = pd.read_csv(CSV_PATH)

# %%
df = df.drop_duplicates(subset='id', keep='first')

# %%
df['id'] = df['id'].astype(str)

# %%
with open('/home/hammad/fyp/image_embeddings_resnet50_tf.pkl','rb') as f:
    embeddings = pickle.load(f)

print("Embeddings loaded: ", len(embeddings))
print("Metadata loaded: ", df.shape)
# Out:
# Embeddings loaded:  22946
# Metadata loaded:  (22951, 10)

# %%
df_filtered = df[df['id'].astype(str).isin(embeddings.keys())]

# %%
df_filtered.shape
# Out:
# (22946, 10)

# %%
## converting embeddings dictionary into DF
embeddings_df = pd.DataFrame.from_dict(embeddings,orient='index')
embeddings_df.index.name = 'id'
embeddings_df.reset_index(inplace=True)

# %%
embeddings_df['id'] = embeddings_df['id'].astype(str)

# %%
embeddings_df.head()
# Out:
#       id         0         1         2         3         4         5  \
# 0  15970  0.325631  0.961932  0.000000  0.549981  0.000000  0.056022
# 1  39386  0.670931  1.461553  0.154584  0.383389  0.460850  0.008900
# 2  21379  0.195744  0.803393  0.004324  2.545139  0.075638  0.109980
# 3  53759  0.096383  1.703673  0.056809  1.617223  0.011546  0.000000
# 4   1855  0.035023  1.326588  0.000000  0.991414  0.000000  0.000000
#
#           6         7         8  ...      2038      2039      2040      2041  \
# 0  0.508034  0.388490  0.008825  ...  0.229524  0.223776  0.124558  2.046997
# 1  0.812330  0.004201  0.344588  ...  0.373247  0.065233  1.082466  0.231429
# 2  2.759297  0.664183  0.075709  ...  0.610984  0.000000  0.000053  0.167400
# 3  1.127666  0.307086  0.000000  ...  0.505315  0.205928  0.140345  1.801834
# 4  0.770858  0.419605  0.103250  ...  0.983012  0.004316  0.195267  1.943198
#
#        2042      2043      2044      2045      2046      2047
# 0  0.000000  0.000000  0.433070  0.234684  0.064110  1.254325
# 1  0.107079  0.002723  0.579104  0.000000  0.000000  1.954522
# 2  0.071858  0.000000  0.659216  0.000000  0.110951  3.961849
# 3  0.000000  0.000000  0.082535  0.078035  0.242948  1.523945
# 4  0.046978  0.000000  0.003337  0.024109  0.403093  0.126377
#
# [5 rows x 2049 columns]

# %%
merged_df = pd.merge(df_filtered,embeddings_df, on='id')

# %%
merged_df.head()
# Out:
#       id baseColour  gender_encoded  category_bottom  category_footwear  \
# 0  15970  Navy Blue               1                0                  0
# 1  39386       Blue               1                1                  0
# 2  21379      Black               1                1                  0
# 3  53759       Grey               1                0                  0
# 4   1855       Grey               1                0                  0
#
#    category_top  style_casual  style_formal  style_sportswear  \
# 0             1             1             0                 0
# 1             0             1             0                 0
# 2             0             1             0                 0
# 3             1             1             0                 0
# 4             1             1             0                 0
#
#    baseColour_encoded  ...      2038      2039      2040      2041      2042  \
# 0                  25  ...  0.229524  0.223776  0.124558  2.046997  0.000000
# 1                   2  ...  0.373247  0.065233  1.082466  0.231429  0.107079
# 2                   1  ...  0.610984  0.000000  0.000053  0.167400  0.071858
# 3                  13  ...  0.505315  0.205928  0.140345  1.801834  0.000000
# 4                  13  ...  0.983012  0.004316  0.195267  1.943198  0.046978
#
#        2043      2044      2045      2046      2047
# 0  0.000000  0.433070  0.234684  0.064110  1.254325
# 1  0.002723  0.579104  0.000000  0.000000  1.954522
# 2  0.000000  0.659216  0.000000  0.110951  3.961849
# 3  0.000000  0.082535  0.078035  0.242948  1.523945
# 4  0.000000  0.003337  0.024109  0.403093  0.126377
#
# [5 rows x 2058 columns]

# %%
merged_df.shape
# Out:
# (22946, 2058)

# %%
def get_category_label(row):
    if row['category_bottom'] == 1:
        return 0
    elif row['category_footwear'] == 1:
        return 1
    elif row['category_top'] == 1:
        return 2

# %%
def get_style_label(row):
    if row['style_casual'] == 1:
        return 0
    elif row['style_formal'] == 1:
        return 1
    elif row['style_sportswear'] == 1:
        return 2

# %%
merged_df.loc[:, 'style_label'] = merged_df.apply(get_style_label, axis=1)
merged_df.loc[:, 'category_label'] = merged_df.apply(get_category_label, axis=1)

# %%
merged_df.head()
# Out:
#       id baseColour  gender_encoded  category_bottom  category_footwear  \
# 0  15970  Navy Blue               1                0                  0
# 1  39386       Blue               1                1                  0
# 2  21379      Black               1                1                  0
# 3  53759       Grey               1                0                  0
# 4   1855       Grey               1                0                  0
#
#    category_top  style_casual  style_formal  style_sportswear  \
# 0             1             1             0                 0
# 1             0             1             0                 0
# 2             0             1             0                 0
# 3             1             1             0                 0
# 4             1             1             0                 0
#
#    baseColour_encoded  ...      2040      2041      2042      2043      2044  \
# 0                  25  ...  0.124558  2.046997  0.000000  0.000000  0.433070
# 1                   2  ...  1.082466  0.231429  0.107079  0.002723  0.579104
# 2                   1  ...  0.000053  0.167400  0.071858  0.000000  0.659216
# 3                  13  ...  0.140345  1.801834  0.000000  0.000000  0.082535
# 4                  13  ...  0.195267  1.943198  0.046978  0.000000  0.003337
#
#        2045      2046      2047  style_label  category_label
# 0  0.234684  0.064110  1.254325            0               2
# 1  0.000000  0.000000  1.954522            0               0
# 2  0.000000  0.110951  3.961849            0               0
# 3  0.078035  0.242948  1.523945            0               2
# 4  0.024109  0.403093  0.126377            0               2
#
# [5 rows x 2060 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22946 entries, 0 to 22945
# Columns: 2060 entries, id to category_label
# dtypes: float32(2048), int64(10), object(2)
# memory usage: 181.4+ MB

# %%
# CATEGORY prediction dataset
category_df = merged_df.drop(columns=[
    'style_casual',
    'style_formal',
    'style_sportswear',
    'style_label',
    'category_bottom',
    'category_top',
    'category_footwear',
    'baseColour_encoded',
    'baseColour'
])

# %%
# Style prediction dataset
style_df = merged_df.drop(columns=[
    'category_bottom',
    'category_footwear',
    'category_top',
    'category_label',
    'style_casual',
    'style_formal',
    'style_sportswear',
    'baseColour_encoded',
    'baseColour'
    
])

# %%
# Color prediction dataset
color_df = merged_df.drop(columns=[
    'category_bottom',
    'category_footwear',
    'category_top',
    'category_label',
    'style_casual',
    'style_formal',
    'style_sportswear',
    'style_label',
    'gender_encoded',
])

# %%
category_df.head()
# Out:
#       id  gender_encoded         0         1         2         3         4  \
# 0  15970               1  0.325631  0.961932  0.000000  0.549981  0.000000
# 1  39386               1  0.670931  1.461553  0.154584  0.383389  0.460850
# 2  21379               1  0.195744  0.803393  0.004324  2.545139  0.075638
# 3  53759               1  0.096383  1.703673  0.056809  1.617223  0.011546
# 4   1855               1  0.035023  1.326588  0.000000  0.991414  0.000000
#
#           5         6         7  ...      2039      2040      2041      2042  \
# 0  0.056022  0.508034  0.388490  ...  0.223776  0.124558  2.046997  0.000000
# 1  0.008900  0.812330  0.004201  ...  0.065233  1.082466  0.231429  0.107079
# 2  0.109980  2.759297  0.664183  ...  0.000000  0.000053  0.167400  0.071858
# 3  0.000000  1.127666  0.307086  ...  0.205928  0.140345  1.801834  0.000000
# 4  0.000000  0.770858  0.419605  ...  0.004316  0.195267  1.943198  0.046978
#
#        2043      2044      2045      2046      2047  category_label
# 0  0.000000  0.433070  0.234684  0.064110  1.254325               2
# 1  0.002723  0.579104  0.000000  0.000000  1.954522               0
# 2  0.000000  0.659216  0.000000  0.110951  3.961849               0
# 3  0.000000  0.082535  0.078035  0.242948  1.523945               2
# 4  0.000000  0.003337  0.024109  0.403093  0.126377               2
#
# [5 rows x 2051 columns]

# %%
style_df.head()
# Out:
#       id  gender_encoded         0         1         2         3         4  \
# 0  15970               1  0.325631  0.961932  0.000000  0.549981  0.000000
# 1  39386               1  0.670931  1.461553  0.154584  0.383389  0.460850
# 2  21379               1  0.195744  0.803393  0.004324  2.545139  0.075638
# 3  53759               1  0.096383  1.703673  0.056809  1.617223  0.011546
# 4   1855               1  0.035023  1.326588  0.000000  0.991414  0.000000
#
#           5         6         7  ...      2039      2040      2041      2042  \
# 0  0.056022  0.508034  0.388490  ...  0.223776  0.124558  2.046997  0.000000
# 1  0.008900  0.812330  0.004201  ...  0.065233  1.082466  0.231429  0.107079
# 2  0.109980  2.759297  0.664183  ...  0.000000  0.000053  0.167400  0.071858
# 3  0.000000  1.127666  0.307086  ...  0.205928  0.140345  1.801834  0.000000
# 4  0.000000  0.770858  0.419605  ...  0.004316  0.195267  1.943198  0.046978
#
#        2043      2044      2045      2046      2047  style_label
# 0  0.000000  0.433070  0.234684  0.064110  1.254325            0
# 1  0.002723  0.579104  0.000000  0.000000  1.954522            0
# 2  0.000000  0.659216  0.000000  0.110951  3.961849            0
# 3  0.000000  0.082535  0.078035  0.242948  1.523945            0
# 4  0.000000  0.003337  0.024109  0.403093  0.126377            0
#
# [5 rows x 2051 columns]

# %%
color_df.head()
# Out:
#       id baseColour  baseColour_encoded         0         1         2  \
# 0  15970  Navy Blue                  25  0.325631  0.961932  0.000000
# 1  39386       Blue                   2  0.670931  1.461553  0.154584
# 2  21379      Black                   1  0.195744  0.803393  0.004324
# 3  53759       Grey                  13  0.096383  1.703673  0.056809
# 4   1855       Grey                  13  0.035023  1.326588  0.000000
#
#           3         4         5         6  ...      2038      2039      2040  \
# 0  0.549981  0.000000  0.056022  0.508034  ...  0.229524  0.223776  0.124558
# 1  0.383389  0.460850  0.008900  0.812330  ...  0.373247  0.065233  1.082466
# 2  2.545139  0.075638  0.109980  2.759297  ...  0.610984  0.000000  0.000053
# 3  1.617223  0.011546  0.000000  1.127666  ...  0.505315  0.205928  0.140345
# 4  0.991414  0.000000  0.000000  0.770858  ...  0.983012  0.004316  0.195267
#
#        2041      2042      2043      2044      2045      2046      2047
# 0  2.046997  0.000000  0.000000  0.433070  0.234684  0.064110  1.254325
# 1  0.231429  0.107079  0.002723  0.579104  0.000000  0.000000  1.954522
# 2  0.167400  0.071858  0.000000  0.659216  0.000000  0.110951  3.961849
# 3  1.801834  0.000000  0.000000  0.082535  0.078035  0.242948  1.523945
# 4  1.943198  0.046978  0.000000  0.003337  0.024109  0.403093  0.126377
#
# [5 rows x 2051 columns]

# %%
color_df.drop(columns=['baseColour_encoded'], inplace=True)

# %%
# Step 2: Rename 'baseColour' to 'original_baseColour'
color_df.rename(columns={'baseColour': 'original_baseColour'}, inplace=True)

# %%
reverse_color_mapping = {
    'Beige': 'Brown', 'Black': 'Black', 'Blue': 'Blue', 'Bronze': 'Brown', 'Brown': 'Brown',
    'Burgundy': 'Red', 'Charcoal': 'Grey', 'Coffee Brown': 'Brown', 'Copper': 'Brown',
    'Cream': 'White', 'Fluorescent Green': 'Green', 'Gold': 'Yellow', 'Green': 'Green',
    'Grey': 'Grey', 'Grey Melange': 'Grey', 'Khaki': 'Green', 'Lavender': 'Purple',
    'Lime Green': 'Green', 'Magenta': 'Pink', 'Maroon': 'Red', 'Mauve': 'Purple',
    'Metallic': 'Grey', 'Multi': 'Multi', 'Mushroom Brown': 'Brown', 'Mustard': 'Yellow',
    'Navy Blue': 'Blue', 'Nude': 'Brown', 'Off White': 'White', 'Olive': 'Green',
    'Orange': 'Orange', 'Peach': 'Pink', 'Pink': 'Pink', 'Purple': 'Purple',
    'Red': 'Red', 'Rust': 'Red', 'Sea Green': 'Green', 'Silver': 'Grey',
    'Tan': 'Brown', 'Taupe': 'Brown', 'Teal': 'Blue', 'Turquoise Blue': 'Blue',
    'White': 'White', 'Yellow': 'Yellow'
}

# %%
color_df['baseColour_grouped'] = color_df['original_baseColour'].map(reverse_color_mapping)

# %%
unmapped_colors = color_df[color_df['baseColour_grouped'].isnull()]['original_baseColour'].unique()
if len(unmapped_colors) > 0:
    print(f"Unmapped colors found: {unmapped_colors}")

# %%
le = LabelEncoder()
color_df['baseColour_encoded'] = le.fit_transform(color_df['baseColour_grouped'])

# %%
color_df.head()
# Out:
#       id original_baseColour         0         1         2         3  \
# 0  15970           Navy Blue  0.325631  0.961932  0.000000  0.549981
# 1  39386                Blue  0.670931  1.461553  0.154584  0.383389
# 2  21379               Black  0.195744  0.803393  0.004324  2.545139
# 3  53759                Grey  0.096383  1.703673  0.056809  1.617223
# 4   1855                Grey  0.035023  1.326588  0.000000  0.991414
#
#           4         5         6         7  ...      2040      2041      2042  \
# 0  0.000000  0.056022  0.508034  0.388490  ...  0.124558  2.046997  0.000000
# 1  0.460850  0.008900  0.812330  0.004201  ...  1.082466  0.231429  0.107079
# 2  0.075638  0.109980  2.759297  0.664183  ...  0.000053  0.167400  0.071858
# 3  0.011546  0.000000  1.127666  0.307086  ...  0.140345  1.801834  0.000000
# 4  0.000000  0.000000  0.770858  0.419605  ...  0.195267  1.943198  0.046978
#
#        2043      2044      2045      2046      2047  baseColour_grouped  \
# 0  0.000000  0.433070  0.234684  0.064110  1.254325                Blue
# 1  0.002723  0.579104  0.000000  0.000000  1.954522                Blue
# 2  0.000000  0.659216  0.000000  0.110951  3.961849               Black
# 3  0.000000  0.082535  0.078035  0.242948  1.523945                Grey
# 4  0.000000  0.003337  0.024109  0.403093  0.126377                Grey
#
#    baseColour_encoded
# 0                   1
# 1                   1
# 2                   0
# 3                   4
# 4                   4
#
# [5 rows x 2052 columns]

# %%
# Create mappings
color_to_index = dict(zip(le.classes_, le.transform(le.classes_)))
index_to_color = dict(zip(le.transform(le.classes_), le.classes_))

# Display mappings
print("Color to Index Mapping:")
for k, v in color_to_index.items():
    print(f"{v}: {k}")
# Out:
# Color to Index Mapping:
# 0: Black
# 1: Blue
# 2: Brown
# 3: Green
# 4: Grey
# 5: Multi
# 6: Orange
# 7: Pink
# 8: Purple
# 9: Red
# 10: White
# 11: Yellow

# %%
color_df['baseColour_encoded'].value_counts()
# Out:
# baseColour_encoded
# 0     4742
# 1     4501
# 10    3759
# 4     2173
# 2     1884
# 9     1572
# 3     1457
# 7      930
# 8      884
# 11     705
# 6      238
# 5      101
# Name: count, dtype: int64

# %%
color_df = color_df.drop(columns=['baseColour_grouped', 'original_baseColour'])

# %%
color_df.head()
# Out:
#       id         0         1         2         3         4         5  \
# 0  15970  0.325631  0.961932  0.000000  0.549981  0.000000  0.056022
# 1  39386  0.670931  1.461553  0.154584  0.383389  0.460850  0.008900
# 2  21379  0.195744  0.803393  0.004324  2.545139  0.075638  0.109980
# 3  53759  0.096383  1.703673  0.056809  1.617223  0.011546  0.000000
# 4   1855  0.035023  1.326588  0.000000  0.991414  0.000000  0.000000
#
#           6         7         8  ...      2039      2040      2041      2042  \
# 0  0.508034  0.388490  0.008825  ...  0.223776  0.124558  2.046997  0.000000
# 1  0.812330  0.004201  0.344588  ...  0.065233  1.082466  0.231429  0.107079
# 2  2.759297  0.664183  0.075709  ...  0.000000  0.000053  0.167400  0.071858
# 3  1.127666  0.307086  0.000000  ...  0.205928  0.140345  1.801834  0.000000
# 4  0.770858  0.419605  0.103250  ...  0.004316  0.195267  1.943198  0.046978
#
#        2043      2044      2045      2046      2047  baseColour_encoded
# 0  0.000000  0.433070  0.234684  0.064110  1.254325                   1
# 1  0.002723  0.579104  0.000000  0.000000  1.954522                   1
# 2  0.000000  0.659216  0.000000  0.110951  3.961849                   0
# 3  0.000000  0.082535  0.078035  0.242948  1.523945                   4
# 4  0.000000  0.003337  0.024109  0.403093  0.126377                   4
#
# [5 rows x 2050 columns]

# %%
category_df.to_csv('category_prediction_dataset.csv',index=False)
style_df.to_csv('style_prediction_dataset.csv',index=False)
color_df.to_csv('color_prediction_dataset.csv', index=False)
